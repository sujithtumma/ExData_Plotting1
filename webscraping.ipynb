# %% [markdown]
# <a href="https://colab.research.google.com/github/sujithtumma/ExData_Plotting1/blob/master/webscraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
import time 
for i in numbers :
  print(i, end="")
  time.sleep(5)
# Out:
# 12345

# %%
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
page = requests.get(url)

# %%
page.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<link href="https://rukminim1.flixcart.com" rel="dns-prefetch" />\n\t<link href="https://img1a.flixcart.com" rel="dns-prefetch" />\n\t<link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.da12ab.css" />\n\n\t<link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" as="image">\n\n\t<meta http-equiv="Content-type" content="text/html; charset=utf-8"/>\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n\t<meta property="fb:page_id" content="102988293558"/>\n\t<meta property="fb:admins" content="658873552,624500995,100000233612389"/>\n\t<meta name="robots" content="noodp" />\n\n\t<link rel=\'shortcut icon\' href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" />\n\n\t<link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/>\n\n\t<meta property="og:type" content="website"/>\n\t<meta name="og_site_name" pro
# ...

# %% [markdown]
# this is source code for the page

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
soup.title
# Out:
# <title>Mobiles - Buy Products Online at Best Price in India - All Categories | Flipkart.com</title>

# %% [markdown]
# when cursor is kept on tab of flipkart then this text is displayed

# %%
from bs4 import BeautifulSoup
import requests 
url = 'https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser')
name = []
price = []
rating = []
for a in soup.findAll('a', href=True, attrs={'class':'_31qSD5'}):
  name1 = a.find('div', attrs={'class':'_3wU53n'})
  price1 = a.find('div',attrs={'class':'_1vC4OE _2rQ-NK'})
  rating1= a.find('div', attrs={'class':'hGSR34'})
  name.append(name1.text)
  price.append(price1.text)
  rating.append(rating1.text)

# %%
import pandas as pd
df = pd.DataFrame(list(zip(name,price,rating)))
df.columns = ['Name','price','rating']

# %% [markdown]
# pandas is used for arranging the data in table

# %%
df
# Out:
#                                        Name    price rating
# 0      Redmi Note 8 Pro (Halo White, 64 GB)  ₹15,999    4.5
# 1             Realme 6 (Comet Blue, 128 GB)  ₹16,999    4.4
# 2           Vivo U10 (Thunder Black, 32 GB)   ₹9,990    4.4
# 3                             Detel D1 Guru     ₹599    3.6
# 4    Redmi Note 8 Pro (Shadow Black, 64 GB)  ₹15,999    4.5
# 5     Realme 5 Pro (Sparkling Blue, 128 GB)  ₹16,999    4.5
# 6      Realme 5 Pro (Sparkling Blue, 64 GB)  ₹14,999    4.5
# 7      Realme 5 Pro (Sparkling Blue, 64 GB)  ₹13,999    4.5
# 8             OPPO A7 (Glaring Gold, 64 GB)  ₹10,990    4.4
# 9     Redmi Note 8 Pro (Halo White, 128 GB)  ₹16,999    4.5
# 10           Apple iPhone SE (Black, 64 GB)  ₹42,500    4.6
# 11     Realme 6 Pro (Lightning Blue, 64 GB)  ₹17,999    4.5
# 12  Redmi Note 7 Pro (Neptune Blue, 128 GB)  ₹13,999    4.5
# 13                            DETEL D1 STAR     ₹699    3.5
# 14           Apple iPhone SE (White, 64 GB)  ₹42,500    4.6
# ...

# %%
name
# Out:
# ['Redmi Note 8 Pro (Halo White, 64 GB)',
#  'Realme 6 (Comet Blue, 128 GB)',
#  'Vivo U10 (Thunder Black, 32 GB)',
#  'Detel D1 Guru',
#  'Redmi Note 8 Pro (Shadow Black, 64 GB)',
#  'Realme 5 Pro (Sparkling Blue, 128 GB)',
#  'Realme 5 Pro (Sparkling Blue, 64 GB)',
#  'Realme 5 Pro (Sparkling Blue, 64 GB)',
#  'OPPO A7 (Glaring Gold, 64 GB)',
#  'Redmi Note 8 Pro (Halo White, 128 GB)',
#  'Apple iPhone SE (Black, 64 GB)',
#  'Realme 6 Pro (Lightning Blue, 64 GB)',
#  'Redmi Note 7 Pro (Neptune Blue, 128 GB)',
#  'DETEL D1 STAR',
#  'Apple iPhone SE (White, 64 GB)',
#  'Vivo Z1Pro (Sonic Black, 64 GB)',
#  'Vivo Z1Pro (Sonic Black, 64 GB)',
#  'Vivo Z1Pro (Sonic Black, 128 GB)',
#  'Realme 5 Pro (Crystal Green, 128 GB)',
#  'Detel D1 Champ',
#  'Realme 5 Pro (Crystal Green, 64 GB)',
#  'Redmi Note 7 Pro (Space Black, 64 GB)',
#  'Micromax X380',
#  'Micromax X380']

# %%
price
# Out:
# ['₹15,999',
#  '₹16,999',
#  '₹9,990',
#  '₹599',
#  '₹15,999',
#  '₹16,999',
#  '₹14,999',
#  '₹13,999',
#  '₹10,990',
#  '₹16,999',
#  '₹42,500',
#  '₹17,999',
#  '₹13,999',
#  '₹699',
#  '₹42,500',
#  '₹13,990',
#  '₹14,990',
#  '₹16,990',
#  '₹16,999',
#  '₹599',
#  '₹14,999',
#  '₹12,999',
#  '₹740',
#  '₹740']

# %% [markdown]
# create the empty lists , so now open flipkart , inspect the elements -> find the class for name of the mobile , price of it and rating of it
